# %% [markdown]
# <a href="https://colab.research.google.com/github/vvanarasi/BITS/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1 = [1,2,3,4,5]
list2 = [1,4,9,16,25]
import matplotlib.pyplot as plt
plt.plot(list1,list2)
plt.xlabel('Numbers')
plt.ylabel('Squares')
plt.title('Numbers vs Squares')
plt.show()

# %%
xdata=[1,2,3,4,5]
ydata=[2,4,6,8,10]
plt.plot(xdata,ydata)
plt.xlabel('Numbers')
plt.ylabel('Double')
plt.title('Numbers vs Doubles')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[2,3,5,7,11]
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y,alpha=0.5)

# %%
import numpy as np
import matplotlib.pyplot as plt

x1=[1,2,3,4]
y1=[10,20,30,40]
y2=[5,10,15,20]
fig, ax = plt.subplots(nrows=1, ncols=2)

ax[0].plot(x1, y1)
ax[1].bar(x1, y2)
plt.show()

# %%
list1 = [10,4,45,99,12]
print("The maximum number in list is",max(list1))
# Out:
# The maximum number in list is 99

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
n=int(input("Input a number to compute the factiorial : "))
print(factorial(n))
# Out:
# Input a number to compute the factiorial : 5
# 120

# %%
fh = open("/content/Salary_Data.csv","r")
entirefilecontents = fh.read()
print(entirefilecontents)
# Out:
# YearsExperience,Salary
# 1.1,39343.00
# 1.3,46205.00
# 1.5,37731.00
# 2.0,43525.00
# 2.2,39891.00
# 2.9,56642.00
# 3.0,60150.00
# 3.2,54445.00
# 3.2,64445.00
# 3.7,57189.00
# 3.9,63218.00
# 4.0,55794.00
# 4.0,56957.00
# 4.1,57081.00
# 4.5,61111.00
# 4.9,67938.00
# 5.1,66029.00
# 5.3,83088.00
# 5.9,81363.00
# 6.0,93940.00
# 6.8,91738.00
# 7.1,98273.00
# 7.9,101302.00
# 8.2,113812.00
# 8.7,109431.00
# 9.0,105582.00
# 9.5,116969.00
# 9.6,112635.00
# 10.3,122391.00
# 10.5,121872.00

# %%
from pathlib import Path
if Path("/content/Salary_Data.csv").is_file():
  print("File exists")
  fh=open("/content/Salary_Data.csv","r")
  firstline=fh.readline()
  print(firstline)
else:
  print("File does not exist")
# Out:
# File exists
# YearsExperience,Salary

# %%
import numpy as np
coeffs = [[2, 1], [1, -1]]
A = np.array(coeffs)
inv_A = np.linalg.inv(A)
constants = np.array([5, 1])
X = np.linalg.inv(A).dot(constants)

print(X)
# Out:
# [2. 1.]

# %%
inpmatrix = np.array([[1,2],[7,8]])
print(np.linalg.inv(inpmatrix))
det = np.linalg.det(inpmatrix)
print(det)
# Out:
# [[-1.33333333  0.33333333]
#  [ 1.16666667 -0.16666667]]
# -6.0

# %%
import numpy as np
coeffs = [6, 8, 10, 4]
A = np.array(coeffs)
print(A)
def sqroot(x):
  return x*x;
B = sqroot(A)
print(B)
# Out:
# [ 6  8 10  4]
# [ 36  64 100  16]

# %%
a = np.arange(4)
b = np.reshape(a,(2,2))
c = b*10
d = np.ones((2,2))
e = c+d
print(e)
f = np.dot(b,c)
print(f)
# Out:
# [[ 1. 11.]
#  [21. 31.]]
# [[ 20  30]
#  [ 60 110]]

# %%
import pandas as pd
df = pd.read_csv("/content/Companies.csv")
groupeddata = df.groupby('State')
df.groupby("State")["Profit"].sum()
# Out:
# State
# California    1766387.98
# Florida       1900384.39
# New York      1933859.59
# Name: Profit, dtype: float64
